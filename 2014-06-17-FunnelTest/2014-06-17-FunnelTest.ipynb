# %%
import pymysql
import pandas

conn = pymysql.connect(host='mysql.guaminsects.net',user='aubreymoore',passwd='canada12',db='oryctes')
sql = "SELECT * from YigoBarrelObs"
df = pandas.io.sql.read_frame(sql, conn)
df.tail()
# Out:
#        id  barrelID trapType lure uvled funnel substrate   startDate  \
# 491  1071         8        P    y     y      y         n  2014-06-17
# 492  1072        13        P    y     y      n         n  2014-06-17
# 493  1073        17        P    y     y      n         n  2014-06-17
# 494  1074        12        P    y     y      n         n  2014-06-17
# 495  1075        11        P    y     y      y         n  2014-06-17
#
#         endDate  males  females notes
# 491  2014-06-22      3        1
# 492  2014-06-22      1        0
# 493  2014-06-22      0        0
# 494  2014-06-22      2        0
# 495  2014-06-22      0        0
#
# [5 rows x 12 columns]

# %%
sql = """
UPDATE YigoBarrelObs
  SET funnel = 'y'
WHERE endDate >= '2014-06-17'
  AND barrelID IN (10, 18, 27, 28, 29, 31, 26, 21, 4, 1, 2, 5, 6, 3, 8, 11);
"""
pandas.io.sql.execute(sql, conn)

# %%
sql = "SELECT * from YigoBarrelObs"
df = pandas.io.sql.read_frame(sql, conn)
df.tail()
# Out:
#        id  barrelID trapType lure uvled funnel substrate   startDate  \
# 491  1071         8        P    y     y      y         n  2014-06-17
# 492  1072        13        P    y     y      n         n  2014-06-17
# 493  1073        17        P    y     y      n         n  2014-06-17
# 494  1074        12        P    y     y      n         n  2014-06-17
# 495  1075        11        P    y     y      y         n  2014-06-17
#
#         endDate  males  females notes
# 491  2014-06-22      3        1
# 492  2014-06-22      1        0
# 493  2014-06-22      0        0
# 494  2014-06-22      2        0
# 495  2014-06-22      0        0
#
# [5 rows x 12 columns]

# %%
sql="""
SELECT 
  funnel, 
  SUM(males+females) AS beetles, 
  SUM(DATEDIFF(endDate, startDate)) AS trapDays,
  SUM(males+females)/SUM(DATEDIFF(endDate, startDate)) AS btlsPerTrapDay
FROM YigoBarrelObs
WHERE endDate >= '2014-06-17'
GROUP BY funnel
"""
df = pandas.io.sql.read_frame(sql, conn)
df
# Out:
#   funnel  beetles  trapDays  btlsPerTrapDay
# 0      y       35       112          0.3125
# 1      n       20       105          0.1905
#
# [2 rows x 4 columns]
